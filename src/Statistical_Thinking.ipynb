# %%
import pandas as pd
import seaborn as sns
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

mgd = pd.read_csv("../data/MDG_Export_20191227.csv")
mgd.head(11)
# Out:
#     CountryCode         Country  SeriesCode MDG  \
# 0             4     Afghanistan         567   Y
# 1             4     Afghanistan         749   Y
# 2             4     Afghanistan         616   Y
# 3             8         Albania         567   Y
# 4             8         Albania         749   Y
# 5             8         Albania         616   Y
# 6            12         Algeria         567   Y
# 7            12         Algeria         749   Y
# 8            12         Algeria         616   Y
# 9            16  American Samoa         567   Y
# 10           16  American Samoa         749   Y
#
#                                                Series     1990 Footnotes Type  \
# 0   Proportion of land area covered by forest, per...      2.1       NaN    E
# 1   Carbon dioxide emissions (CO2), thousand metri...   2676.9       NaN    G
# 2   Terrestrial and marine areas protected to tota...     0.36       NaN    C
# ...

# %%
len(mgd['Country'].unique())
mgd = mgd[mgd != 0]

mgd.head(11)
# Out:
#     CountryCode         Country  SeriesCode MDG  \
# 0             4     Afghanistan         567   Y
# 1             4     Afghanistan         749   Y
# 2             4     Afghanistan         616   Y
# 3             8         Albania         567   Y
# 4             8         Albania         749   Y
# 5             8         Albania         616   Y
# 6            12         Algeria         567   Y
# 7            12         Algeria         749   Y
# 8            12         Algeria         616   Y
# 9            16  American Samoa         567   Y
# 10           16  American Samoa         749   Y
#
#                                                Series     1990 Footnotes Type  \
# 0   Proportion of land area covered by forest, per...      2.1       NaN    E
# 1   Carbon dioxide emissions (CO2), thousand metri...   2676.9       NaN    G
# 2   Terrestrial and marine areas protected to tota...     0.36       NaN    C
# ...

# %%
mgd = mgd.dropna(how='all',axis ='columns')
mgd = mgd.dropna(subset = ["1990"])
mgd.head()
# Out:
#    CountryCode      Country  SeriesCode MDG  \
# 0            4  Afghanistan         567   Y
# 1            4  Afghanistan         749   Y
# 2            4  Afghanistan         616   Y
# 3            8      Albania         567   Y
# 4            8      Albania         749   Y
#
#                                               Series     1990 Footnotes Type  \
# 0  Proportion of land area covered by forest, per...     2.10       NaN    E
# 1  Carbon dioxide emissions (CO2), thousand metri...  2676.90       NaN    G
# 2  Terrestrial and marine areas protected to tota...     0.36       NaN    C
# 3  Proportion of land area covered by forest, per...    28.80       NaN    C
# 4  Carbon dioxide emissions (CO2), thousand metri...  7488.00       NaN    G
#
#      1991 Type.1  ... Type.18    2009 Type.19    2010 Footnotes.20 Type.20  \
# 0     NaN    NaN  ...     NaN     NaN     NaN     2.1          NaN       E
# 1  2493.6      G  ...       G  6776.6       G  8470.8          NaN       G
# ...

# %%
co2 = mgd.loc[mgd['Series'] == "Carbon dioxide emissions (CO2), thousand metric tons of CO2 (CDIAC)"]

co2.sort_values(by='1990').head()
# Out:
#      CountryCode       Country  SeriesCode MDG  \
# 679          887         Yemen         749   Y
# 445          570          Niue         749   Y
# 505          654  Saint Helena         749   Y
# 559          706       Somalia         749   Y
# 142          184  Cook Islands         749   Y
#
#                                                 Series    1990 Footnotes Type  \
# 679  Carbon dioxide emissions (CO2), thousand metri... -2999.6       NaN    G
# 445  Carbon dioxide emissions (CO2), thousand metri...     3.7       NaN    G
# 505  Carbon dioxide emissions (CO2), thousand metri...     7.3       NaN    G
# 559  Carbon dioxide emissions (CO2), thousand metri...    18.3       NaN    G
# 142  Carbon dioxide emissions (CO2), thousand metri...    22.0       NaN    G
#
#         1991 Type.1  ... Type.18     2009 Type.19     2010 Footnotes.20  \
# 679  10109.9      G  ...       G  23556.8       G  25716.7          NaN
# ...

# %%
co2.sort_values(by='1990').tail()
# Out:
#      CountryCode                                         Country  SeriesCode  \
# 463          591                                          Panama         749
# 88            96                               Brunei Darussalam         749
# 58            56                                         Belgium         749
# 688          716                                        Zimbabwe         749
# 682          890  Yugoslavia [former Socialist Federal Republic]         749
#
#     MDG                                             Series      1990  \
# 463   Y  Carbon dioxide emissions (CO2), thousand metri...    2768.6
# 88    Y  Carbon dioxide emissions (CO2), thousand metri...    6211.9
# 58    Y  Carbon dioxide emissions (CO2), thousand metri...  106049.6
# 688   Y  Carbon dioxide emissions (CO2), thousand metri...   15504.1
# 682   Y  Carbon dioxide emissions (CO2), thousand metri...  133288.1
#
#     Footnotes Type      1991 Type.1  ... Type.18      2009 Type.19      2010  \
# ...

# %%
mgd['1990'] = pd.to_numeric(mgd['1990'])

mgd.describe()
# Out:
#        CountryCode  SeriesCode          1990
# count   627.000000  627.000000  6.270000e+02
# mean    428.905901  636.966507  2.629594e+04
# std     250.885402   74.361030  2.272526e+05
# min       4.000000  567.000000 -2.999600e+03
# 25%     214.000000  567.000000  2.795000e+00
# 50%     428.000000  616.000000  2.240000e+01
# 75%     642.000000  749.000000  1.228500e+02
# max     894.000000  749.000000  4.823557e+06

# %%
#this the median
print("this the median:", np.median(co2['1990']))
#this is the mean
print("this the min:" ,np.mean(co2['1990']))
#this is the min
print("this the min:" ,np.min(co2['1990']))
#this is the max
print("this the max:" ,np.max(co2['1990']))
#this STD
print("this is the standard deviation:", np.std(co2['1990']))

print("this is the interquatile range:" ,sp.stats.iqr(co2['1990']))

print("this is the starndard error:" ,co2['1990'].sem())
# Out:
# this the median: 3017.9
# this the mean: 91045.00331491708
# this the min: -2999.6
# this the max: 4823557.1
# this is the standard deviation: 415595.1934372853
# this is the interquatile range: 41653.5
# this is the starndard error: 30976.63678826482

# %%
ax = plt.hist(co2['1990'])

# %%
land = mgd.loc[mgd['Series'] == "Proportion of land area covered by forest, percentage"]
marine = mgd.loc[mgd['Series'] == "Terrestrial and marine areas protected to total territorial area, percentage"]

marine.head()
# Out:
#     CountryCode         Country  SeriesCode MDG  \
# 2             4     Afghanistan         616   Y
# 5             8         Albania         616   Y
# 8            12         Algeria         616   Y
# 11           16  American Samoa         616   Y
# 14           20         Andorra         616   Y
#
#                                                Series  1990 Footnotes Type  \
# 2   Terrestrial and marine areas protected to tota...  0.36       NaN    C
# 5   Terrestrial and marine areas protected to tota...  0.15       NaN    C
# 8   Terrestrial and marine areas protected to tota...  5.97       NaN    C
# 11  Terrestrial and marine areas protected to tota...  0.06       NaN    C
# 14  Terrestrial and marine areas protected to tota...  5.53       NaN    C
#
#    1991 Type.1  ... Type.18 2009 Type.19 2010 Footnotes.20 Type.20 2011  \
# 2   NaN    NaN  ...     NaN  NaN     NaN  NaN          NaN     NaN  NaN
# 5   NaN    NaN  ...     NaN  NaN     NaN  NaN          NaN     NaN  NaN
# ...

# %%
print("this the min:" ,np.mean(land['1990']))
print("this is the standard deviation:", np.std(land['1990']))
# Out:
# this the min: 32.97713004484306
# this is the standard deviation: 25.440278554474926
